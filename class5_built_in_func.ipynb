# %%
name = " Pak,i,stam"

# %%
name.upper()
# Out:
# ' PAK,I,STAM'

# %%
name.lower()
# Out:
# ' pak,i,stam'

# %%
name.strip()
# Out:
# 'Pak,i,stam'

# %%
name.replace(",", "")
# Out:
# ' Pakistam'

# %%
name.replace("m", "n")
# Out:
# ' Pak,i,stan'

# %%
sent = "Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation. Python is dynamically type-checked and garbage-collected."
sent.split(" ")
# Out:
# ['Python',
#  'is',
#  'a',
#  'high-level,',
#  'general-purpose',
#  'programming',
#  'language.',
#  'Its',
#  'design',
#  'philosophy',
#  'emphasizes',
#  'code',
#  'readability',
#  'with',
#  'the',
#  'use',
#  'of',
#  'significant',
#  'indentation.',
#  'Python',
#  'is',
#  'dynamically',
#  'type-checked',
#  'and',
#  'garbage-collected.']

# %%
n = "Pakistan"
ind= 1
newC = "@"
ob=n[:ind]
oa=n[ind+1:] 
new = ob + newC + oa

new
# Out:
# 'P@kistan'

# %%
p
# Out:
# '@'

# %%
print("P", p)
# Out:
# P @

# %%
s = "righz\rleft"

print(s)
# Out:
# leftz

# %%
ss = "To fix \\ this \t problem\', use \bthe \110\111escape character"
x = ss.count("T")
print(x)
# Out:
# 1

# %%
print(ss)
# Out:
# To fix \ this 	 problem', usethe HIescape character
