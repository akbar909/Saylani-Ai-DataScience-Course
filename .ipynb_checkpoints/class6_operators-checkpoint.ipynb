# %% [markdown]
# # operators : Arithmetic operators, Assignment operators, Comparison operators, Logical operators, Precedence

# %%
a= 2

# %%
a+=2
a
# Out:
# 18

# %%
2**3
# Out:
# 8

# %%
4==4
# Out:
# True

# %%
txt = "Hello World"
a = "h"  in txt
a
# Out:
# False

# %%
txt = "Hello World"
a = "h" not in txt  or "L" not in txt
a
# Out:
# True

# %%
sent = "Ghulam Akbar"
a = "Ghulam" not in sent or "Akbar" in sent
a
# Out:
# True
