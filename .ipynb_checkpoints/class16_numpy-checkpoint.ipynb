# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.26.4'

# %%
arr = np.array([1,2,3,4,5])

# %%
arr.ndim
# Out:
# 1

# %%
arr3d = np.array([[[1,2,3 ], [4,5,6],[4,"A",6]], [[7,8,9],[10,11,12],[4,5,6]]])

# %%
arr3d
# Out:
# array([[['1', '2', '3'],
#         ['4', '5', '6'],
#         ['4', 'A', '6']],
#
#        [['7', '8', '9'],
#         ['10', '11', '12'],
#         ['4', '5', '6']]], dtype='<U11')

# %%
arr3d[0,0:3,1]
# Out:
# array(['2', '5', 'A'], dtype='<U11')
