# %%
name="Ghulam Akbar"
print(name)
# Out:
# Ghulam Akbar

# %%
age=20

# %%
print(f" Name: {name} \n Age: {age} ")
# Out:
#  Name: Ghulam Akbar
#  Age: 20

# %%
print("this is a new\nline")
print("this is a \tline")
print("the path is  C:\\line\\name")
# Out:
# this is a new
# line
# this is a 	line
# the path is  C:\line\name
