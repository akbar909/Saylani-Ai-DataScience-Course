# %%
print("====== Smart Student Record Analyzer ======")
print('''1. Add Student
2. View All Students
3. Search Student
4. Update Student
5. Delete Student
6. Analyze Data
7. Exit''')


def add_student():
    print("Add Student Data")
    stdudent_id = input("Enter Student ID: ")
    # validation for student_id
    if not stdudent_id.isdigit():
        print("Invalid Student ID. It should be numeric.")
    else:
        student_id = int(stdudent_id)
    
    name = input("Enter Student Name: ")
    age = input("Enter Student Age: ")
    grade = input("Enter Student Grade: ")
    marks = input("Enter Student Marks: ")
    with open("students.txt", "a") as file:
        file.write(f"{stdudent_id},{name},{age},{grade},{marks}\n")
    print("Student added successfully.")



def main():
    while True:
        choice = input("Enter your choice (1-7): ")
        if choice == '1':
            add_student()
        elif choice == '2':
            view_students()
        elif choice == '3':
            search_student()
        elif choice == '4':
            update_student()
        elif choice == '5':
            delete_student()
        elif choice == '6':
            analyze_data()
        elif choice == '7':
            print("Exiting the program.")
            break
        else:
            print("Invalid choice. Please try again.")
            
main()
# Out:
# ====== Smart Student Record Analyzer ======
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Analyze Data
# 7. Exit
# Invalid choice. Please try again.
# Invalid choice. Please try again.
# Add Student Data
# Student added successfully.
