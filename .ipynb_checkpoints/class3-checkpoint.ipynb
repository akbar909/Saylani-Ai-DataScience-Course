# %%
# a=2
# b=2

# print(f"{a} {b}")

# %%
sub1 = 80
sub2 = 70
sub3 = 83
sub4 = 91
sub5 = 70.5

TotalMArks= 500
obtMarks= sub1+sub2+sub3+sub4+sub5
Percentage= (obtMarks/TotalMArks)*100

print(f"Marks Obtained =  {obtMarks} \nTotal Percentage = {Percentage}")
# Out:
# Marks Obtained =  394.5
# Total Percentage = 78.9

# %%
a=5

# %%
b=-10

# %%
a+=b

# %%
a
# Out:
# 4

# %%
a = float(input("Enter a value of a: "))
b = float(input("Enter a value of b: "))
c = float(input("Enter a value of c: "))
d = float(input("Enter a value of d: "))

equ = (a*b)-c+d*(a/c)

print(equ)
# Out:
# Enter a value of a:  5
# Enter a value of b:  3
# Enter a value of c:  7
# Enter a value of d:  1
# 8.714285714285714

# %%
a = 3
b = 2

c=a
a=b
b=c

print(f" a = {a} , b = {b}")
# Out:
#  a = 2 , b = 3

# %%
a,b = b,a

# %%
print(a)
print(b)
# Out:
# 2
# 3
