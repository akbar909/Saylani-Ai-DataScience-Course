# %%
import random
print("WELCOME TO MY NUMBER GUESSING GAME")

score = 0 

while True:
    minNum = int(input("Enter a Minimum Value: "))
    maxNum = int(input("Enter a Maximum Value: "))
    
    print(f"You selected Minimum Number {minNum} and Maximum Number {maxNum}")
    
    userLevel = input("Enter Your Difficulty Level:\nEASY\nMEDIUM\nHARD\nIMPOSSIBLE: ").lower()
    
    if userLevel == 'medium':
        chances = 7
        maxNum *= random.randint(2, 10)
    elif userLevel == 'hard':
        chances = 5
        maxNum *= random.randint(12, 45)
    elif userLevel == 'impossible':
        chances = 3
        maxNum *= random.randint(100,1000)
    else:
        chances = 10
        
    print(f"You selected {userLevel} difficulty.\nNow you have {chances} lives to Guess the Correct Number.\nYour Maximum Number now is {maxNum}.")
    
    if minNum < maxNum:
        secretNumber = random.randint(minNum, maxNum)
        
        while chances > 0:
            print(f"You have {chances} lives left to guess correctly.")
            userGuess = input("Enter Your Guess Number: ")

            if not userGuess.isdigit():
                print("Enter Only Numbers, Invalid Input Data Type.")
                continue
            else:
                userGuess = int(userGuess)
                
                if userGuess < secretNumber:
                    print("Your guess is too low.")
                elif userGuess > secretNumber:
                    print("Your guess is too high.")
                else:
                    print("You guessed the correct number!")
                    print(f"Your Tries Count: {score}")
                    break
                    
            chances -= 1
            score += 1
            
            if chances == 0: 
                print(f"You are out of lives. The secret number was {secretNumber}.")
                break

        userChoice = input("Do you want to play again? \nYes\nNo\n").lower()
        if userChoice != 'yes':
            print("You Scared From Me")
            break 
        else:
            continue
    else:
        print("Error: Minimum Value must be less than Maximum Value.")
        continue
    break

# %%
import random
while True:
  score = 0
  chances = 10
  minNum = (input("Enter a minimum Number = "))
  maxNum = (input("Enter a maxmum Number = "))
  if not minNum.isdigit() or not maxNum.isdigit():
    print("ENter a valid input, Only numbers")
    continue
  else:
    minNum = int(minNum)
    maxNum = int(maxNum)

  userInputs = []
  if minNum < maxNum:
    RandomNum = random.randrange(minNum, maxNum)

    while True:
      userGuess = input("Enter a Number to Guess = ")
      if  not userGuess.isdigit():
        print("Enter a valid input, Only numbers")
        continue
      userGuess = int(userGuess)
      userInputs.append(userGuess)

      if userGuess < RandomNum:
          print("Too  Low")
          print(f"You have {chances} chances left")
      elif userGuess > RandomNum:
          print("Too High")
          print(f"You have {chances} chances left")
      else:
          print("Correct, you guess right number")
          if chances >= 5:
            score += 10
          else:
            score += 5
          print(f"Your Score is {score}")
          break
      chances -= 1
      if chances == 0:
          print("You ran out of chances!")
          break

    print(f"Random Number = {RandomNum}")
    print(f"Your Entered Numbers {userInputs}")
  else:
    print("Enter  a minmum num less than a max num")
    continue
  break
# Out:
# Enter  a minmum num less than a max num
# Too  Low
# You have 10 chances left
# Too  Low
# You have 9 chances left
# Too  Low
# You have 8 chances left
# Correct, you guess right number
# Your Score is 10
# Random Number = 6
# Your Entered Numbers [3, 2, 5, 6]
