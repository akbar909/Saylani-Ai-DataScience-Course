# %% [markdown]
# ### Day 8
# #### Append Characters to String to Make Subsequence

# %%
source = "abc"
target = "abcbc"
i = 0

# %%
for counter in source:
    if counter ==target[i]:
        i += 1
        if i == len(target):
            print(0)
print(len(target)-i)
# Out:
# 2
