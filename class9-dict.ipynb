# %% [markdown]
# # DICT - Collective data type
# # Dictionary items are ordered, changeable, and do not allow duplicates.

# %%
menu = {
    "biryani": 500,
    "qorma": "free"
}

# %%
"qorma" in menu
# Out:
# True

# %%
type(menu)
# Out:
# dict

# %%
len(menu)
# Out:
# 2

# %%
menu["biryani"]
# Out:
# 500

# %%
menu["qorma"]= 300

menu
# Out:
# {'biryani': 500, 'qorma': 300}

# %%
menu["rosh"]= 5000

# %%
menu
# Out:
# {'biryani': 500, 'qorma': 300, 'rosh': 5000}

# %%
menu.keys()
# Out:
# dict_keys(['biryani', 'qorma', 'rosh'])

# %%
menu.values()
# Out:
# dict_values([500, 300, 5000])

# %%
menu.pop("qorma")
# Out:
# 300

# %%
menu
# Out:
# {'biryani': 500, 'rosh': 5000}

# %%
menu = {
    "starter": [
        {"Fish and chips": 1500, "Soup":500, "Fries": 250 }
    ],
    "bbq": [{"Bihari Boti": 300, "Dhagga":1000 ,"Malai Boti": 800, "Tikka": 500}],
    "Drinks": {"Water": "free"},
    "Deserts": [{"Ice Cream": 2000}, {"Kulfi": 100}]
}

menu
# Out:
# {'starter': [{'Fish and chips': 1500, 'Soup': 500, 'Fries': 250}],
#  'bbq': [{'Bihari Boti': 300,
#    'Dhagga': 1000,
#    'Malai Boti': 800,
#    'Tikka': 500}],
#  'Drinks': {'Water': 'free'},
#  'Deserts': [{'Ice Cream': 2000}, {'Kulfi': 100}]}

# %%
type(menu["Drinks"])
# Out:
# dict

# %%
menu["starter"][0]["Soup"]
# Out:
# 500

# %%
menu["Drinks"]["Water"]
# Out:
# 'free'

# %%
menu["Deserts"][1]["Kulfi"]
# Out:
# 100

# %%
menu.get("Deserts")
# Out:
# [{'Ice Cream': 2000}, {'Kulfi': 100}]

# %%
menu.items()
# Out:
# dict_items([('starter', [{'Fish and chips': 1500, 'Soup': 500, 'Fries': 250}]), ('bbq', [{'Bihari Boti': 300, 'Dhagga': 1000, 'Malai Boti': 800, 'Tikka': 500}]), ('Drinks', {'Water': 'free'}), ('Deserts', [{'Ice Cream': 2000}, {'Kulfi': 100}])])
